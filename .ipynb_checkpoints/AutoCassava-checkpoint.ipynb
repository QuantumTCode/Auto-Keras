# %%
import os
import csv
import sys
import multiprocessing
sys.path
# Out:
# ['',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/home/neil/.local/lib/python3.6/site-packages',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/baselines-0.1.5-py3.6.egg',
#  '/usr/lib/python3/dist-packages',
#  '/home/neil/.local/lib/python3.6/site-packages/IPython/extensions',
#  '/home/neil/.ipython']

# %%
size_of_image=1024

# %%
import split_folders
split_folders.ratio('data', output="split_data", ratio=(.8, .1, .1))

# %%
# !cd split_data/train && find . -type f -name '*.JPG' -print0 | xargs -0 rename 's/\.JPG/\.jpg/'
# !cd split_data/val && find . -type f -name '*.JPG' -print0 | xargs -0 rename 's/\.JPG/\.jpg/'
# !cd split_data/test && find . -type f -name '*.JPG' -print0 | xargs -0 rename 's/\.JPG/\.jpg/'

# %%
train_dir = 'split_data/train' # Path to the train directory
class_dirs = [i for i in os.listdir(path=train_dir) if os.path.isdir(os.path.join(train_dir, i))]
with open('split_data/train/label.csv', 'w') as train_csv:
    fieldnames = ['File Name', 'Label']
    writer = csv.DictWriter(train_csv, fieldnames=fieldnames)
    writer.writeheader()
    label = 0
    for current_class in class_dirs:
        for image in os.listdir(os.path.join(train_dir, current_class)):
            writer.writerow({'File Name': str(image), 'Label':label})
        label += 1
    train_csv.close()

# %%
from PIL import Image
import os, sys
import time
from tqdm import tqdm
# !mkdir split_data/train_all
# !find split_data/train/ -type f -print0 | xargs -0 cp -t split_data/train_all
# !cd split_data/train_all && rm *.csv
path = "split_data/train_all/"
dirs = os.listdir( path )

def resize(item):
        if os.path.isfile(path+item):
            im = Image.open(path+item)
            f, e = os.path.splitext(path+item)
            imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
            imResize.save(f+"smaller.jpg", 'JPEG', quality=100)


processes = []
pool = multiprocessing.Pool()
pool.map(resize, dirs)
pool.close()
# Out:
# mkdir: cannot create directory ‘split_data/train_all’: File exists
# ^C
# rm: cannot remove '*.csv': No such file or directory
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-15:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-0d97d2e42742> in <module>()
#      20 processes = []
#      21 pool = multiprocessing.Pool()
# ---> 22 pool.map(resize, dirs)
#      23 pool.close()
#
# /usr/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /usr/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1804, in resize
#     self.load()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/ImageFile.py", line 241, in load
#     n, err_code = decoder.decode(b)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-7:
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1804, in resize
#     self.load()
# Traceback (most recent call last):
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1804, in resize
#     self.load()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/ImageFile.py", line 241, in load
#     n, err_code = decoder.decode(b)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1804, in resize
#     self.load()
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/ImageFile.py", line 241, in load
#     n, err_code = decoder.decode(b)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1804, in resize
#     self.load()
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
# KeyboardInterrupt
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/ImageFile.py", line 241, in load
#     n, err_code = decoder.decode(b)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1804, in resize
#     self.load()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/ImageFile.py", line 241, in load
#     n, err_code = decoder.decode(b)
# Process ForkPoolWorker-19:
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/ImageFile.py", line 241, in load
#     n, err_code = decoder.decode(b)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-16:
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1804, in resize
#     self.load()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1806, in resize
#     return self._new(self.im.resize(size, resample, box))
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/ImageFile.py", line 241, in load
#     n, err_code = decoder.decode(b)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1804, in resize
#     self.load()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/ImageFile.py", line 241, in load
#     n, err_code = decoder.decode(b)
# KeyboardInterrupt
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1804, in resize
#     self.load()
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1804, in resize
#     self.load()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/ImageFile.py", line 241, in load
#     n, err_code = decoder.decode(b)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/ImageFile.py", line 241, in load
#     n, err_code = decoder.decode(b)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# KeyboardInterrupt
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
# KeyboardInterrupt
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1804, in resize
#     self.load()
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1806, in resize
#     return self._new(self.im.resize(size, resample, box))
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/ImageFile.py", line 241, in load
#     n, err_code = decoder.decode(b)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1806, in resize
#     return self._new(self.im.resize(size, resample, box))
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
# Process ForkPoolWorker-3:
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1804, in resize
#     self.load()
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1804, in resize
#     self.load()
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/ImageFile.py", line 241, in load
#     n, err_code = decoder.decode(b)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/ImageFile.py", line 241, in load
#     n, err_code = decoder.decode(b)
# Traceback (most recent call last):
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-4:
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1804, in resize
#     self.load()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/ImageFile.py", line 241, in load
#     n, err_code = decoder.decode(b)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1806, in resize
#     return self._new(self.im.resize(size, resample, box))
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1806, in resize
#     return self._new(self.im.resize(size, resample, box))
# KeyboardInterrupt
# Process ForkPoolWorker-14:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1806, in resize
#     return self._new(self.im.resize(size, resample, box))
# KeyboardInterrupt

# %%
# !mkdir split_data/resized-train/
# !mv split_data/train_all/*smaller.jpg split_data/resized-train/
# !cd split_data/resized-train && for i in *.jpg; do     mv "$i" "`echo $i | sed 's/smaller//'`"; done

# %%
from autokeras.image.image_supervised import load_image_dataset
# Out:
# Using TensorFlow backend.

# %%
x_train, y_train = load_image_dataset(csv_file_path="split_data/train/label.csv",
                                      images_path="split_data/resized-train/")
print(x_train.shape)
print(y_train.shape)
# Out:
# (3137, 512, 512, 3)
# (3137,)

# %%
from autokeras.image.image_supervised import ImageClassifier

# %%
# !mkdir models
clf = ImageClassifier(path="models/",verbose=True)
clf.fit(x_train, y_train, time_limit=21*60*60)
# Out:
# Saving Directory: models/
# Preprocessing the images.
# Preprocessing finished.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |               Training model 0               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           0            |   2.5569116711616515   |   0.6735632183908045   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 1               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |               Training model 2               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |               Training model 3               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           3            |   1.8016104102134705   |   0.7593869731800765   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 4               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           4            |   2.1975000739097594   |   0.7256704980842912   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 5               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           5            |   1.850828856229782    |   0.7647509578544062   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 6               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           6            |   2.3566508546471594   |   0.7486590038314176   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 7               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           7            |   2.1817734003067017   |   0.7540229885057471   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 8               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           8            |   1.441373234987259    |   0.8076628352490423   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 9               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           9            |   2.2305854320526124   |   0.7409961685823754   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 10               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           10           |   6.556360483169556    |   0.1532567049808429   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 11               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           11           |    2.91973357796669    |   0.7448275862068965   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 12               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 13               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 14               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 15               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           15           |   2.2883362591266634   |   0.7862068965517242   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 16               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 17               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           17           |   1.7795459806919098   |   0.8015325670498085   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 18               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           18           |   1.2666402220726014   |   0.8329501915708812   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 19               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 20               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           20           |   1.900021767616272    |   0.7961685823754789   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 21               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           21           |   1.6594007313251495   |   0.8122605363984674   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 22               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 23               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           23           |   1.7883158594369888   |   0.7724137931034483   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 24               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           24           |   1.4419496387243271   |   0.8137931034482758   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 25               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 26               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           26           |   2.0375402837991716   |   0.7908045977011494   |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |              Training model 27               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           27           |   1.6828798592090606   |   0.7969348659003831   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 28               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 29               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           29           |   1.533155193924904    |   0.8045977011494253   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 30               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 31               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           31           |   1.240318062901497    |   0.8306513409961684   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 32               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 33               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           33           |   2.0288843691349028   |   0.7693486590038313   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 34               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           34           |   1.5310130387544632   |   0.8145593869731801   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 35               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           35           |   1.2267573744058609   |   0.849808429118774    |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 36               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           36           |   1.8629944324493408   |   0.7915708812260536   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 37               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           37           |   1.5346830070018769   |   0.8084291187739463   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 38               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:  43%|█████████████                 | 10/23 [00:00<00:00, 18.25 batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 39               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 40               |
# +----------------------------------------------+
#
#
# No loss decrease after 5 epochs.
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           40           |   1.7402385383844376   |   0.7808429118773947   |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |              Training model 41               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           41           |   1.3661314487457275   |   0.8206896551724139   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 42               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           42           |   1.2409217357635498   |   0.8413793103448276   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 43               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 44               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 45               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 46               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 47               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           47           |   2.470221388339996    |   0.7716475095785441   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 48               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 49               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           49           |   1.5384774178266525   |   0.8306513409961684   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 50               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 51               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           51           |   2.9509804606437684   |   0.7540229885057472   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 52               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 53               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           53           |   1.4803024053573608   |   0.8153256704980845   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 54               |
# +----------------------------------------------+
#
#
# No loss decrease after 5 epochs.
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           54           |   1.355366015434265    |   0.8367816091954022   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 55               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:  43%|█████████████                 | 10/23 [00:00<00:00, 14.88 batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 56               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           56           |   2.7262666523456573   |   0.7731800766283525   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 57               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:  43%|█████████████                 | 10/23 [00:00<00:00, 19.27 batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 58               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:  43%|█████████████                 | 10/23 [00:00<00:00, 19.30 batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 59               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           59           |   1.8654051899909974   |   0.803831417624521    |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 60               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 61               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 62               |
# +----------------------------------------------+
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           62           |          nan           |  0.13793103448275862   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 63               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 64               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           64           |   2.060163876414299    |   0.8160919540229885   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 65               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]
# Current model size is too big. Discontinuing training this model to search for other models.
#
#
# +----------------------------------------------+
# |              Training model 66               |
# +----------------------------------------------+
#
#
# No loss decrease after 5 epochs.
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           66           |   1.7403400287032127   |   0.7877394636015327   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 67               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           67           |   1.3975565791130067   |   0.8168582375478929   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 68               |
# +----------------------------------------------+
# Epoch-1, Current Metric - 0:   0%|                                       | 0/23 [00:00<?, ? batch/s]

# %%
train_dir = 'split_data/val' # Path to the train directory
class_dirs = [i for i in os.listdir(path=train_dir) if os.path.isdir(os.path.join(train_dir, i))]
with open('split_data/val/label.csv', 'w') as train_csv:
    fieldnames = ['File Name', 'Label']
    writer = csv.DictWriter(train_csv, fieldnames=fieldnames)
    writer.writeheader()
    label = 0
    for current_class in class_dirs:
        for image in os.listdir(os.path.join(train_dir, current_class)):
            writer.writerow({'File Name': str(image), 'Label':label})
        label += 1
    train_csv.close()

# %%
# !mkdir split_data/val_all
# !find split_data/val/ -type f -print0 | xargs -0 cp -t split_data/val_all
# !cd split_data/val_all && rm *.csv
path = "split_data/val_all/"
dirs = os.listdir( path )

processes = []
pool = multiprocessing.Pool()
pool.map(resize, dirs)
pool.close()
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-0d97d2e42742>", line 16, in resize
#     imResize = im.resize((size_of_image,size_of_image), Image.ANTIALIAS)
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1794, in resize
#     return self.copy()
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/Image.py", line 1108, in copy
#     self.load()
#   File "/home/neil/.local/lib/python3.6/site-packages/PIL/ImageFile.py", line 238, in load
#     len(b))
# OSError: image file is truncated (217 bytes not processed)
# """
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-152ae110a8ca> in <module>()
#       7 processes = []
#       8 pool = multiprocessing.Pool()
# ----> 9 pool.map(resize, dirs)
#      10 pool.close()
#
# /usr/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# OSError: image file is truncated (217 bytes not processed)

# %%
# !mkdir split_data/resized-val
# !mv split_data/val_all/*smaller.jpg split_data/resized-val/
# !cd split_data/resized-val && for i in *.jpg; do     mv "$i" "`echo $i | sed 's/smaller//'`"; done

# %%
x_val, y_val = load_image_dataset(csv_file_path="split_data/val/label.csv",
                                      images_path="split_data/resized-val/")
print(x_val.shape)
print(y_val.shape)

# %%
clf.final_fit(x_train, y_train, x_val, y_val, retrain=True)
y = clf.evaluate(x_val, y_val)
print(y)

# %%
import os
from graphviz import Digraph

from autokeras.utils import pickle_from_file


def to_pdf(graph, path):
    dot = Digraph(comment='The Round Table')

    for index, node in enumerate(graph.node_list):
        dot.node(str(index), str(node.shape))

    for u in range(graph.n_nodes):
        for v, layer_id in graph.adj_list[u]:
            dot.edge(str(u), str(v), str(graph.layer_list[layer_id]))

    dot.render(path)


def visualize(path):
    cnn_module = pickle_from_file(os.path.join(path, 'module'))
    cnn_module.searcher.path = path
    for item in cnn_module.searcher.history:
        model_id = item['model_id']
        graph = cnn_module.searcher.load_model_by_id(model_id)
    to_pdf(graph, os.path.join(path, str(model_id)))
# Out:
# Using TensorFlow backend.

# %%
visualize('models/')
